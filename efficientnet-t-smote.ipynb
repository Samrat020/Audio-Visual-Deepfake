# %%
# Kaggle environment check
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames[:5]:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/moved/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/README.txt
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/meta_data.csv
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00391/00052_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00391/00052_id00166_PQV2ZbJBLNk_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00391/00052_id01530_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00391/00052_id01236_7WdumGR5-JM_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00391/00052_id00476_UgdYVJ6xPYg_faceswap_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01392/00167_id00391_TjJgUZaenWI_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01392/00167_id01179_RnqLJMrWELw_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01392/00167_id00366_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01392/00167_3_id01933_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01392/00167_id01207_mt129WTRSII_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00173/00118_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00173/00118_id01920_w9C_knCPD94_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00173/00118_id00076_Isiq7cA-DNE_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00173/00118_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00173/00118_id00476_UgdYVJ6xPYg_faceswap_id01530_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00701/00092_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00701/00092_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00701/00092_id01036_AohKaMtIHxA_faceswap_id01972_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00701/00092_id00987_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00701/00092_id01779_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02342/00191_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02342/00191_id00781_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02342/00191_id00391_TjJgUZaenWI_id00475_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02342/00191_id04727_AAnyugIAXao_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02342/00191_id02005_7_Egh9mW5y4_faceswap_id01076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01598/00044_id00476_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01598/00109_1_id01637_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01598/00044_id01779_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01598/00044_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01598/00044_id01452_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01995/00071_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01995/00071_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01995/00071_id00076_Isiq7cA-DNE_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01995/00071_id02296_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01995/00071_id00475_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00518/00031_id02494_lObg47hQleE_id01179_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00518/00031_id00701_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00518/00031_1_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00518/00031_id01972_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00518/00031_id02268_irA9myDvW-I_id01610_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02494/00050_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02494/00050_id02268_irA9myDvW-I_id02494_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02494/00050_id01179_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02494/00050_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02494/00050_id02005_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01691/00045_id01779_HgyHpDEo_jk_faceswap_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01691/00045_id01036_AohKaMtIHxA_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01691/00045_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01691/00045_id00366_RSOgEoek8WM_id01452_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01691/00045_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02005/00052_id01597_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02005/00052_id00830_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02005/00052_id02342_RJPBPhJB8TA_faceswap_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02005/00052_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02005/00052_id01179_RnqLJMrWELw_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01920/00099_id00366_RSOgEoek8WM_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01920/00099_id01920_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01920/00099_id01717_JDW6p8yU13A_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01920/00099_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01920/00099_id00476_UgdYVJ6xPYg_faceswap_id01597_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02296/00019_id01521_jthjSmLdLOg_id00830_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02296/00019_id01691_IVtS5z8Jrrk_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02296/00019_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02296/00019_id02005_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02296/00019_2_id01610_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01835/00130_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01835/00130_id00761_QtTNFhCCgzw_id02296_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01835/00130_id00944_DiW5D62667U_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01835/00130_id01036_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01835/00130_id00701_lW6uzLIOwd0_id00391_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01528/00017_id00944_DiW5D62667U_id02296_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01528/00017_id00518_qm7oQcDg4oI_id00781_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01528/00017_id01452_4MqeoSxSy3w_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01528/00017_id01452_4MqeoSxSy3w_faceswap_id01610_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01528/00017_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00761/00072_id01717_JDW6p8yU13A_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00761/00072_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00761/00072_id02342_RJPBPhJB8TA_id01995_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00761/00072_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00761/00072_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01779/00010_id02494_lObg47hQleE_id01076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01779/00010_id01691_IVtS5z8Jrrk_faceswap_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01779/00010_id01637_5VjcPZm8knM_id01972_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01779/00010_id01076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01779/00010_id01691_IVtS5z8Jrrk_faceswap_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00781/00092_id00476_UgdYVJ6xPYg_faceswap_id02494_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00781/00092_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00781/00092_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00781/00092_id00781_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00781/00092_id00366_RSOgEoek8WM_id02494_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01521/00109_id00987_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01521/00109_id01835_UZbWA0QfXXA_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01521/00109_id01856_6Q2f3b1QNRM_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01521/00109_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01521/00109_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00478/00206_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00478/00109_11_id01856_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00478/00206_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00478/00109_11_id01610_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00478/00206_id00781_fvsSae9yc0A_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01717/00005_id01920_w9C_knCPD94_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01717/00005_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01717/00005_id00366_RSOgEoek8WM_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01717/00005_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01717/00005_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01076/00005_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01076/00005_id00366_RSOgEoek8WM_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01076/00005_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01076/00005_id01835_UZbWA0QfXXA_id01544_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01076/00005_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01544/00044_id01597_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01544/00044_id00366_RSOgEoek8WM_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01544/00044_id01637_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01544/00044_3_id01530_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01544/00044_id01779_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01856/00109_3_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01856/00006_id01920_w9C_knCPD94_id00475_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01856/00006_id00366_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01856/00109_3_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01856/00006_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01170/00021_id01933_I5XXxgK7QpE_faceswap_id01597_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01170/00021_id01171_XSINMRoTb0E_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01170/00021_id01933_I5XXxgK7QpE_faceswap_id01637_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01170/00021_id01544_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01170/00021_id01933_I5XXxgK7QpE_faceswap_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02316/00094_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02316/00094_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02316/00094_id00830_rfl3Teg9uew_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02316/00094_id01920_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02316/00094_id00987_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02268/00036_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02268/00036_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02268/00036_id01920_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02268/00036_id01717_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02268/00036_id01835_UZbWA0QfXXA_id01856_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01530/00002_id01835_UZbWA0QfXXA_id01036_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01530/00002_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01530/00002_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01530/00002_id02005_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01530/00002_id01544_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01637/00002_id01170_7eoTTk4xyNo_id01452_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01637/00002_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01637/00002_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01637/00002_2_id01452_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01637/00002_1_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01933/00028_id01528_SBAS9Kcb8QY_id01530_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01933/00028_id01597_52WEZxe4_GE_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01933/00028_3_id00475_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01933/00028_id01170_7eoTTk4xyNo_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01933/00028_id02316_yrrNcmZ-xmI_id02040_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00475/00099_0_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00475/00099_id02316_yrrNcmZ-xmI_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00475/00099_id01170_7eoTTk4xyNo_id02296_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00475/00099_id02296_IAgOrCuY8vU_id00830_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00475/00099_id01179_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01972/00078_3_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01972/00078_3_id00366_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01972/00078_id01544_uBo9585VW2A_id01920_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01972/00078_2_id01717_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01972/00078_3_id01544_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00830/00143_id01170_7eoTTk4xyNo_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00830/00143_id00475_xQjvXRcnPvw_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00830/00143_id00076_Isiq7cA-DNE_id00781_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00830/00143_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00830/00143_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01236/00005_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01236/00005_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01236/00005_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01236/00005_id01610_l8zb_iaDJJA_faceswap_id00830_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01236/00005_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01452/00001_id02005_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01452/00001_id00944_DiW5D62667U_id01637_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01452/00001_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01452/00001_id00518_qm7oQcDg4oI_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01452/00001_id01528_SBAS9Kcb8QY_faceswap_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00987/00160_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00987/00160_id02005_7_Egh9mW5y4_faceswap_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00987/00160_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00987/00160_id02005_7_Egh9mW5y4_faceswap_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00987/00160_id02005_7_Egh9mW5y4_faceswap_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00076/00109_id01207_mt129WTRSII_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00076/00109_12_id01856_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00076/00109_9_id02005_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00076/00109_7_id01452_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00076/00109_12_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00476/00109_id00476_UgdYVJ6xPYg_faceswap_id00781_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00476/00109_id01995_YUR9wTypwIo_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00476/00109_id00781_fvsSae9yc0A_faceswap_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00476/00109_id00476_UgdYVJ6xPYg_faceswap_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00476/00109_id00173_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01171/00053_id01933_I5XXxgK7QpE_id01521_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01171/00053_id01521_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01171/00053_id00391_TjJgUZaenWI_id01717_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01171/00053_id01544_uBo9585VW2A_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01171/00053_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00944/00135_id01528_SBAS9Kcb8QY_id01972_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00944/00135_id01933_I5XXxgK7QpE_id01236_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00944/00135_id01076_9bqxgm5fT58_id01835_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00944/00135_id01528_SBAS9Kcb8QY_faceswap_id01179_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00944/00135_id01036_AohKaMtIHxA_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00166/00010_id00391_TjJgUZaenWI_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00166/00010_id02494_lObg47hQleE_id00761_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00166/00010_id01076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00166/00010_id00478_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00166/00010_id01637_5VjcPZm8knM_faceswap_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01036/00010_id01637_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01036/00010_id00701_lW6uzLIOwd0_faceswap_id01171_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01036/00010_id01544_uBo9585VW2A_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01036/00010_id00076_Isiq7cA-DNE_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01036/00010_id00366_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01597/00005_3_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01597/00005_id00944_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01597/00005_id01170_7eoTTk4xyNo_id00391_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01597/00005_3_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01597/00005_0_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02040/00476_id01717_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02040/00476_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02040/00476_id01392_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02040/00476_id01995_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02040/00476_id01691_IVtS5z8Jrrk_id01717_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02051/00015_id00166_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02051/00015_id00173_UHoMXLSjlDo_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02051/00015_id01691_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02051/00015_id01995_YUR9wTypwIo_id00476_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id02051/00015_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01179/00160_id00166_PQV2ZbJBLNk_id01544_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01179/00160_id01207_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01179/00160_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01179/00160_id00518_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01179/00160_id02005_7_Egh9mW5y4_faceswap_id02316_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id04727/00007_id00987_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id04727/00007_id01171_XSINMRoTb0E_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id04727/00007_id01920_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id04727/00007_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id04727/00007_id00701_lW6uzLIOwd0_id00987_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01207/00320_id00076_Isiq7cA-DNE_faceswap_id04727_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01207/00320_id00076_Isiq7cA-DNE_faceswap_id01597_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01207/00320_id00476_UgdYVJ6xPYg_id00076_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01207/00320_id00076_Isiq7cA-DNE_faceswap_id00366_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01207/00320_id01598_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00366/00118_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00366/00118_id01920_w9C_knCPD94_id01170_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00366/00118_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00366/00118_id00076_Isiq7cA-DNE_faceswap_id02342_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id00366/00118_id01528_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01610/00090_id01236_7WdumGR5-JM_faceswap_id02051_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01610/00090_id01637_5VjcPZm8knM_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01610/00090_id01236_7WdumGR5-JM_faceswap_id00475_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01610/00090_id02268_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/men/id01610/00090_id02296_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04055/00001_id00592_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04055/00001_id00460_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04055/00001_id05252_CMxIX3absYM_faceswap_id04705_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04055/00001_id04939_i4v2cXo9HIQ_id05980_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04055/00001_id05252_CMxIX3absYM_faceswap_id05980_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id03713/00249_id02721_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id03713/00249_id01661_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id03713/00249_id04736_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id03713/00249_id04736__D2k4fMhEfQ_id00829_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id03713/00249_id02617_4EZjRXC4fLk_faceswap_id00832_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05106/00078_id05235_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05106/00078_id04820_64ybrA1atlM_faceswap_id05231_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05106/00078_id04820_64ybrA1atlM_faceswap_id00371_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05106/00078_id02508_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05106/00078_id01532_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02838/00080_id04820_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02838/00080_id03569_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02838/00080_id03713_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02838/00080_id01838_q_lUk55OrL0_id02824_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02838/00080_id04374_SWltOOZmlWM_id04055_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04376/00181_id00829_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04376/00181_id00220_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04376/00181_id00220_WlHLlTQKj8g_id04547_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04376/00181_id01783_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id04376/00181_id04374_SWltOOZmlWM_id01838_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05251/00033_id01178_6XpgYMiKxhc_faceswap_id04437_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05251/00033_id04939_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05251/00033_id01178_6XpgYMiKxhc_faceswap_id03658_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05251/00033_id04736_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id05251/00033_id04376_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00460/00005_id02301_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00460/00005_id00220_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00460/00005_id05252_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00460/00005_id00832_Jr4-dXRChME_id03658_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00460/00005_id00577_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02071/00195_id04245_nQD_PRlBDyw_id03658_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02071/00195_id03658_8Wtu9VXKqjY_id02948_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02071/00195_id00359_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02071/00195_id04689_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02071/00195_id01661_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00359/00053_id01178_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00359/00053_id00460_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00359/00053_id01838_q_lUk55OrL0_faceswap_id03658_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00359/00053_id02948_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id00359/00053_id02508_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02948/00298_id03569_YO0EpPm9p-8_id01532_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02948/00298_id04820_64ybrA1atlM_faceswap_id00460_wavtolip.mp4
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/FakeAVCeleb_v1.2/FakeVideo-FakeAudio/African/women/id02948/00298_id00707_wavtolip.mp4
# ...
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id02561/02561_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id02561/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id04884/00028_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id04884/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id00597/00019_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id00597/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id07338/00003_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id07338/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id06594/00002_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id06594/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id03028/00466_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id03028/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id04774/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id04774/00032_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id08652/00006_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id08652/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id06878/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/men/id06878/00001_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09174/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09174/00015_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id01281/00040_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id01281/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06462/00014_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06462/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04066/00013_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04066/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06060/00219_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06060/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03211/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03211/00032_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06158/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06158/00015_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04414/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04414/00001_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06061/00002_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06061/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05620/00005_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05620/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06388/00005_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06388/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id01451/00099_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id01451/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07901/00040_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07901/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id02587/00020_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id02587/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09171/00092_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09171/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06427/00138_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06427/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07383/00011_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07383/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09175/00072_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09175/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08819/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08819/00052_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05576/00368_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05576/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03379/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03379/00032_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04701/00017_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04701/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05844/00072_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05844/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00137/00025_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00137/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04144/00028_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04144/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08402/00092_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08402/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id02807/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id02807/00032_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00579/00030_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00579/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00430/00209_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00430/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08139/00067_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08139/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09181/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09181/00048_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00763/00074_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00763/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00566/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00566/00032_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07739/00019_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07739/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00935/00005_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00935/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07039/00105_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07039/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09125/00098_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09125/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04057/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id04057/00015_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06443/00232_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06443/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00582/00006_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00582/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03940/00025_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id03940/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06225/00005_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06225/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07799/00063_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id07799/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06066/00028_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06066/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09116/00026_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id09116/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00363/00014_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id00363/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05631/00073_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id05631/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06065/00160_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06065/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06054/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id06054/00010_fake_frame0.jpg
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08397/desktop.ini
# /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2/frames/RealVideo-FakeAudio/Asian (East)/women/id08397/00167_fake_frame0.jpg

# %%
# !pip install imbalanced-learn -q
print("Install complete.")
# Out:
# Install complete.

# %%
import torch
print(f"PyTorch  : {torch.__version__}")
print(f"CUDA     : {torch.version.cuda}")
if torch.cuda.is_available():
    print(f"GPU      : {torch.cuda.get_device_name(0)}")
    print(f"sm cap   : {torch.cuda.get_device_capability(0)}")
else:
    print("GPU      : CPU mode")
# Out:
# PyTorch  : 2.10.0+cu128
# CUDA     : 12.8
# GPU      : Tesla T4
# sm cap   : (7, 5)

# %%
import os, glob, warnings, random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torchaudio
import torchvision.transforms as T
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
import cv2
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                              f1_score, roc_auc_score, roc_curve,
                              confusion_matrix, classification_report)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.neighbors import NearestNeighbors
from imblearn.over_sampling import RandomOverSampler
import matplotlib.pyplot as plt
from tqdm import tqdm
warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True
print("All imports successful.")
# Out:
# All imports successful.

# %%
def find_data_dir(base="/kaggle/input", target="FakeAVCeleb_v1.2"):
    for root, dirs, _ in os.walk(base):
        for d in dirs:
            if target.lower() in d.lower():
                return os.path.join(root, d)
    print("WARNING: Could not auto-detect DATA_DIR. Available mounted inputs:")
    for root, dirs, _ in os.walk(base):
        for d in dirs:
            print(f"  {os.path.join(root, d)}")
        break
    raise FileNotFoundError(
        f"'{target}' not found under {base}.\n"
        "Please attach via Kaggle UI > Add Data > search 'fakeavceleb'."
    )

DATA_DIR = find_data_dir()
print(f"Dataset found: {DATA_DIR}")
# Out:
# Dataset found: /kaggle/input/datasets/shreyaty08/fakeavceleb/FakeAVCeleb_v1.2

# %%
TOTAL_SAMPLES   = 1200
VAL_SPLIT       = 0.2
SEQ_LEN         = 16
IMG_SIZE        = 224      # EfficientNet-B0 default image size
BATCH_SIZE      = 4        # safer for EfficientNet + sequence training
LR              = 2e-4
EPOCHS          = 35
ES_PATIENCE     = 10
GRAD_CLIP       = 1.0
LABEL_SMOOTH    = 0.05
WEIGHT_DECAY    = 1e-4
USE_AMP         = True
DEVICE          = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")

TARGET_PER_CLASS = TOTAL_SAMPLES // 2
VAL_SIZE         = int(TOTAL_SAMPLES * VAL_SPLIT)
VAL_PER_CLASS    = VAL_SIZE // 2
TRAIN_SIZE       = TOTAL_SAMPLES - VAL_SIZE
TRAIN_PER_CLASS  = TRAIN_SIZE // 2

print(f"Config  : Total={TOTAL_SAMPLES} | Train={TRAIN_SIZE} ({TRAIN_PER_CLASS}R + {TRAIN_PER_CLASS}F) | Val={VAL_SIZE}")
print(f"SEQ_LEN : {SEQ_LEN} | IMG_SIZE: {IMG_SIZE} | EPOCHS: {EPOCHS} | ES patience: {ES_PATIENCE}")
print("-" * 60)
# Out:
# Device: cuda
# Config  : Total=1200 | Train=960 (480R + 480F) | Val=240
# SEQ_LEN : 16 | IMG_SIZE: 224 | EPOCHS: 35 | ES patience: 10
# ------------------------------------------------------------

# %%
all_videos  = glob.glob(os.path.join(DATA_DIR, "**/*.mp4"), recursive=True)
real_videos = [p for p in all_videos if "realvideo" in p.lower() and "realaudio" in p.lower()]
fake_videos = [p for p in all_videos if p not in real_videos]
print(f"Found: {len(real_videos)} real videos, {len(fake_videos)} fake videos")

assert len(real_videos) > 0, "No real videos found. Check DATA_DIR path."
assert len(fake_videos) >= TRAIN_PER_CLASS + VAL_PER_CLASS, "Not enough fake videos."
print("Assertion checks passed.")
# Out:
# Found: 500 real videos, 21060 fake videos
# Assertion checks passed.

# %%
# ============================================================
# T-SMOTE BALANCING
# Synthetic minority samples are temporal interpolations between similar videos.
# ============================================================
np.random.seed(SEED)

val_real_paths = list(np.random.choice(real_videos, VAL_PER_CLASS, replace=False))
val_fake_paths = list(np.random.choice(fake_videos, VAL_PER_CLASS, replace=False))

val_real_set = set(val_real_paths)
val_fake_set = set(val_fake_paths)

remaining_real = [p for p in real_videos if p not in val_real_set]
remaining_fake = [p for p in fake_videos if p not in val_fake_set]

val_paths  = val_real_paths + val_fake_paths
val_labels = [0] * VAL_PER_CLASS + [1] * VAL_PER_CLASS

unique_real_count = min(len(remaining_real), TRAIN_PER_CLASS)
base_real_paths   = list(np.random.choice(remaining_real, unique_real_count, replace=False))
base_fake_paths   = list(np.random.choice(remaining_fake, TRAIN_PER_CLASS, replace=False))

base_train_paths  = base_real_paths + base_fake_paths
base_train_labels = [0] * len(base_real_paths) + [1] * len(base_fake_paths)

print(f"Pre-T-SMOTE pool: {len(base_real_paths)} unique R + {len(base_fake_paths)} unique F")

counts = {0: base_train_labels.count(0), 1: base_train_labels.count(1)}
minority_label = 0 if counts[0] < counts[1] else 1
needed = TRAIN_PER_CLASS - counts[minority_label]
minority_paths = [p for p, y in zip(base_train_paths, base_train_labels) if y == minority_label]
print(f"Minority class: {minority_label} | T-SMOTE synthetic slots needed: {needed}")

def quick_video_descriptor(video_path, frames_to_read=5):
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total <= 0:
        cap.release()
        return np.zeros(6, dtype=np.float32)
    idxs = np.linspace(0, max(total - 1, 0), frames_to_read).astype(int)
    means, stds = [], []
    for idx in idxs:
        cap.set(cv2.CAP_PROP_POS_FRAMES, int(idx))
        ok, frame = cap.read()
        if not ok:
            continue
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        means.append(frame.mean(axis=(0, 1)))
        stds.append(frame.std(axis=(0, 1)))
    cap.release()
    if not means:
        return np.zeros(6, dtype=np.float32)
    return np.concatenate([np.mean(means, axis=0), np.mean(stds, axis=0)]).astype(np.float32)

if needed > 0 and len(minority_paths) > 1:
    descriptors = np.stack([quick_video_descriptor(p) for p in tqdm(minority_paths, desc="T-SMOTE descriptors")])
    n_neighbors = min(5, len(minority_paths))
    nn_model = NearestNeighbors(n_neighbors=n_neighbors).fit(descriptors)
    neighbors = nn_model.kneighbors(descriptors, return_distance=False)
else:
    neighbors = None

train_paths = list(base_train_paths)
train_labels = list(base_train_labels)
train_aug_flags = [0] * len(train_paths)
train_mix_paths = [None] * len(train_paths)
train_mix_lambdas = [0.0] * len(train_paths)
train_gan_params = [None] * len(train_paths)

for _ in range(max(0, needed)):
    i = np.random.randint(0, len(minority_paths))
    if neighbors is not None and len(neighbors[i]) > 1:
        j = int(np.random.choice(neighbors[i][1:]))
    else:
        j = i
    lam = float(np.random.uniform(0.25, 0.75))
    train_paths.append(minority_paths[i])
    train_labels.append(minority_label)
    train_aug_flags.append(2)
    train_mix_paths.append(minority_paths[j])
    train_mix_lambdas.append(lam)
    train_gan_params.append(None)

combined = list(zip(train_paths, train_labels, train_aug_flags,
                    train_mix_paths, train_mix_lambdas, train_gan_params))
np.random.shuffle(combined)
train_paths, train_labels, train_aug_flags, train_mix_paths, train_mix_lambdas, train_gan_params = zip(*combined)
train_paths       = list(train_paths)
train_labels      = list(train_labels)
train_aug_flags   = list(train_aug_flags)
train_mix_paths   = list(train_mix_paths)
train_mix_lambdas = list(train_mix_lambdas)
train_gan_params  = list(train_gan_params)

augmented_count = sum(1 for f in train_aug_flags if f != 0)
BALANCING_NAME = "T-SMOTE temporal interpolation"
RESULT_TAG = "efficientnet_tsmote_balancing"

print(f"FINAL COUNTS:")
print(f"  TRAIN ({len(train_paths)}): {train_labels.count(0)}R + {train_labels.count(1)}F  ({augmented_count} T-SMOTE synthetic slots)")
print(f"  VAL   ({len(val_paths)}):  {val_labels.count(0)} unique R + {val_labels.count(1)} unique F")
print("-" * 60)
# Out:
# Pre-T-SMOTE pool: 380 unique R + 480 unique F
# Minority class: 0 | T-SMOTE synthetic slots needed: 100
# T-SMOTE descriptors: 100%|██████████| 380/380 [00:40<00:00,  9.34it/s]
# FINAL COUNTS:
#   TRAIN (960): 480R + 480F  (100 T-SMOTE synthetic slots)
#   VAL   (240):  120 unique R + 120 unique F
# ------------------------------------------------------------

# %%
def extract_audio_from_video(video_path, target_sr=16000, target_samples=48000):
    try:
        waveform, sr = torchaudio.load(video_path, format="mp4")
        if sr != target_sr:
            waveform = torchaudio.transforms.Resample(orig_freq=sr, new_freq=target_sr)(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        if waveform.shape[1] < target_samples:
            waveform = F.pad(waveform, (0, target_samples - waveform.shape[1]))
        else:
            waveform = waveform[:, :target_samples]
        return waveform
    except Exception:
        return torch.zeros(1, target_samples)

print("extract_audio_from_video() defined.")
# Out:
# extract_audio_from_video() defined.

# %%
class EfficientDeepfakeDataset(Dataset):
    def __init__(self, video_paths, labels, aug_flags, mix_paths=None, mix_lambdas=None, gan_params=None):
        self.video_paths = video_paths
        self.labels      = labels
        self.aug_flags   = aug_flags
        self.mix_paths   = mix_paths if mix_paths is not None else [None] * len(video_paths)
        self.mix_lambdas = mix_lambdas if mix_lambdas is not None else [0.0] * len(video_paths)
        self.gan_params  = gan_params if gan_params is not None else [None] * len(video_paths)

        self.normalize = T.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
        self.video_aug = T.Compose([
            T.RandomHorizontalFlip(p=0.5),
            T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1),
            T.RandomRotation(degrees=10),
            T.RandomAffine(degrees=0, translate=(0.08, 0.08), scale=(0.92, 1.08))
        ])
        self.mfcc_transform       = torchaudio.transforms.MFCC(sample_rate=16000, n_mfcc=40)
        self.AUDIO_TARGET_SAMPLES = 48000
        self.AUDIO_SR             = 16000

    def read_video_tensor(self, vpath, apply_aug=False, gan_param=None):
        cap          = cv2.VideoCapture(vpath)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        step         = max(1, total_frames // SEQ_LEN) if total_frames > 0 else 1
        frames       = []
        for i in range(SEQ_LEN):
            cap.set(cv2.CAP_PROP_POS_FRAMES, min(i * step, max(total_frames - 1, 0)))
            ret, frame = cap.read()
            if ret:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame = cv2.resize(frame, (IMG_SIZE, IMG_SIZE))
                frame = torch.tensor(frame).permute(2, 0, 1).float() / 255.0
                if apply_aug:
                    frame = self.video_aug(frame)
                if gan_param is not None:
                    frame = frame * gan_param.get("contrast", 1.0) + (gan_param.get("brightness", 1.0) - 1.0)
                    frame = torch.clamp(frame, 0.0, 1.0)
                frame = self.normalize(frame)
                frames.append(frame)
            else:
                frames.append(torch.zeros(3, IMG_SIZE, IMG_SIZE))
        cap.release()
        return torch.stack(frames)

    def audio_to_mfcc(self, waveform):
        mfcc = self.mfcc_transform(waveform)
        return mfcc.squeeze(0).permute(1, 0)

    def augment_audio(self, waveform, gan_param=None):
        if gan_param is None:
            waveform = waveform * np.random.uniform(0.8, 1.2)
            noise_std = 0.005
        else:
            waveform = waveform * gan_param.get("audio_gain", 1.0)
            noise_std = gan_param.get("audio_noise", 0.005)

        if np.random.rand() < 0.5 or gan_param is not None:
            waveform = waveform + torch.randn_like(waveform) * noise_std

        audio_feat = self.audio_to_mfcc(waveform)
        if np.random.rand() < 0.5:
            n_mfcc  = audio_feat.shape[1]
            f_start = np.random.randint(0, max(1, n_mfcc - 5))
            f_width = np.random.randint(1, min(10, n_mfcc - f_start))
            audio_feat[:, f_start:f_start + f_width] = 0.0
        if np.random.rand() < 0.5:
            T_a     = audio_feat.shape[0]
            t_start = np.random.randint(0, max(1, T_a - 10))
            t_width = np.random.randint(1, min(10, T_a - t_start))
            audio_feat[t_start:t_start + t_width, :] = 0.0
        return audio_feat

    def __len__(self):
        return len(self.video_paths)

    def __getitem__(self, idx):
        vpath = self.video_paths[idx]
        flag = self.aug_flags[idx]

        if flag == 2 and self.gan_params[idx] is not None:
            video_feat = self.read_video_tensor(vpath, apply_aug=False, gan_param=self.gan_params[idx])
            audio_feat = self.augment_audio(extract_audio_from_video(vpath), gan_param=self.gan_params[idx])
        elif flag == 2 and self.mix_paths[idx] is not None:
            video_a = self.read_video_tensor(vpath)
            audio_a = self.audio_to_mfcc(extract_audio_from_video(vpath))
            video_b = self.read_video_tensor(self.mix_paths[idx])
            audio_b = self.audio_to_mfcc(extract_audio_from_video(self.mix_paths[idx]))
            lam = float(self.mix_lambdas[idx])
            video_feat = lam * video_a + (1.0 - lam) * video_b
            min_t = min(audio_a.shape[0], audio_b.shape[0])
            audio_feat = lam * audio_a[:min_t] + (1.0 - lam) * audio_b[:min_t]
        else:
            apply_aug = bool(flag == 1)
            video_feat = self.read_video_tensor(vpath, apply_aug=apply_aug)
            waveform = extract_audio_from_video(vpath)
            audio_feat = self.augment_audio(waveform) if apply_aug else self.audio_to_mfcc(waveform)

        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return video_feat, audio_feat, label

print("EfficientDeepfakeDataset defined.")
# Out:
# EfficientDeepfakeDataset defined.

# %%
class TemporalAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Sequential(
            nn.Linear(hidden_size, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        )

    def forward(self, gru_out):
        scores  = self.attn(gru_out)
        weights = torch.softmax(scores, dim=1)
        context = (weights * gru_out).sum(dim=1)
        return context, weights.squeeze(-1)

class EfficientNetDeepfakeDetector(nn.Module):
    def __init__(self, n_mfcc=40):
        super().__init__()
        efficientnet = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
        self.video_backbone = efficientnet.features
        self.video_pool     = nn.AdaptiveAvgPool2d(1)
        self.video_fc       = nn.Linear(1280, 256)

        self.video_gru      = nn.GRU(input_size=256, hidden_size=128,
                                     num_layers=1, batch_first=True)
        self.video_attn     = TemporalAttention(hidden_size=128)

        self.audio_gru      = nn.GRU(input_size=n_mfcc, hidden_size=128,
                                     num_layers=1, batch_first=True)
        self.audio_attn     = TemporalAttention(hidden_size=128)

        self.video_bn       = nn.BatchNorm1d(128)
        self.audio_bn       = nn.BatchNorm1d(128)

        self.fusion = nn.Sequential(
            nn.Linear(256, 128), nn.ReLU(), nn.Dropout(0.45),
            nn.Linear(128, 64),  nn.ReLU(), nn.Dropout(0.35),
            nn.Linear(64, 1)
        )

    def forward(self, video, audio):
        B, T, C, H, W = video.shape
        v = self.video_backbone(video.view(B * T, C, H, W))
        v = self.video_pool(v).view(B * T, -1)
        v = F.relu(self.video_fc(v)).view(B, T, 256)
        v_out, _ = self.video_gru(v)
        v_feat, _ = self.video_attn(v_out)
        v_feat = self.video_bn(v_feat)

        a_out, _ = self.audio_gru(audio)
        a_feat, _ = self.audio_attn(a_out)
        a_feat = self.audio_bn(a_feat)

        return self.fusion(torch.cat([v_feat, a_feat], dim=1))

print("EfficientNetDeepfakeDetector with TemporalAttention defined.")
# Out:
# EfficientNetDeepfakeDetector with TemporalAttention defined.

# %%
train_ds = EfficientDeepfakeDataset(
    train_paths, train_labels, train_aug_flags,
    mix_paths=train_mix_paths,
    mix_lambdas=train_mix_lambdas,
    gan_params=train_gan_params
)
val_ds = EfficientDeepfakeDataset(
    val_paths, val_labels, [0] * len(val_paths),
    mix_paths=[None] * len(val_paths),
    mix_lambdas=[0.0] * len(val_paths),
    gan_params=[None] * len(val_paths)
)

class_sample_count = np.array([train_labels.count(0), train_labels.count(1)], dtype=np.float32)
class_weights_sampler = 1.0 / np.maximum(class_sample_count, 1.0)
sample_weights = np.array([class_weights_sampler[label] for label in train_labels], dtype=np.float32)
train_sampler = WeightedRandomSampler(
    weights=torch.from_numpy(sample_weights),
    num_samples=len(sample_weights),
    replacement=True
)

train_loader = DataLoader(train_ds, BATCH_SIZE, sampler=train_sampler, num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_ds,   BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print(f"DataLoaders ready:")
print(f"  Balancing: {BALANCING_NAME}")
print(f"  Balanced sampler: ON")
print(f"  Train : {len(train_loader)} batches x {BATCH_SIZE}")
print(f"  Val   : {len(val_loader)} batches x {BATCH_SIZE}")
# Out:
# DataLoaders ready:
#   Balancing: T-SMOTE temporal interpolation
#   Balanced sampler: ON
#   Train : 240 batches x 4
#   Val   : 60 batches x 4

# %%
class_weights = compute_class_weight("balanced", classes=np.array([0, 1]),
                                     y=np.array(train_labels))
pos_weight = torch.tensor(class_weights[1], dtype=torch.float).to(DEVICE)

model = EfficientNetDeepfakeDetector(n_mfcc=40).to(DEVICE)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Backbone starts frozen for stable transfer learning.
for param in model.video_backbone.parameters():
    param.requires_grad = False

optimizer = optim.AdamW([
    {"params": model.video_backbone.parameters(), "lr": LR * 0.05},
    {"params": model.video_gru.parameters(),      "lr": LR},
    {"params": model.video_attn.parameters(),     "lr": LR},
    {"params": model.audio_gru.parameters(),      "lr": LR},
    {"params": model.audio_attn.parameters(),     "lr": LR},
    {"params": model.video_bn.parameters(),       "lr": LR},
    {"params": model.audio_bn.parameters(),       "lr": LR},
    {"params": model.video_fc.parameters(),       "lr": LR},
    {"params": model.video_pool.parameters(),     "lr": LR},
    {"params": model.fusion.parameters(),         "lr": LR},
], weight_decay=WEIGHT_DECAY)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min", factor=0.5, patience=3, min_lr=1e-6
)
scaler = torch.cuda.amp.GradScaler(enabled=(USE_AMP and DEVICE.type == "cuda"))

best_val_loss = float("inf")
best_val_f1   = 0.0
best_val_auc  = 0.0
es_counter    = 0

print("MODEL CONFIG:")
print(f"  Backbone  : EfficientNet-B0 pretrained ImageNet")
print(f"  Loss      : BCEWithLogitsLoss(pos_weight={pos_weight.item():.3f}) + label_smooth={LABEL_SMOOTH}")
print(f"  Optimizer : AdamW(backbone_lr={LR*0.05:.2e}, head_lr={LR:.2e}, weight_decay={WEIGHT_DECAY})")
print(f"  Scheduler : ReduceLROnPlateau(patience=3, factor=0.5)")
print(f"  AMP       : {USE_AMP}")
print(f"  Attention : TemporalAttention on video + audio GRU outputs")
print(f"  Grad clip : {GRAD_CLIP}")
print(f"  Batch size: {BATCH_SIZE}")
print(f"  Early stop: patience={ES_PATIENCE} | checkpoint by Val F1/AUC")
print(f"  Params    : {sum(p.numel() for p in model.parameters()):,}")
print(f"  Trainable : {sum(p.numel() for p in model.parameters() if p.requires_grad):,}  (backbone frozen)")
print("-" * 60)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 190MB/s]
# MODEL CONFIG:
#   Backbone  : EfficientNet-B0 pretrained ImageNet
#   Loss      : BCEWithLogitsLoss(pos_weight=1.000) + label_smooth=0.05
#   Optimizer : AdamW(backbone_lr=1.00e-05, head_lr=2.00e-04, weight_decay=0.0001)
#   Scheduler : ReduceLROnPlateau(patience=3, factor=0.5)
#   AMP       : True
#   Attention : TemporalAttention on video + audio GRU outputs
#   Grad clip : 1.0
#   Batch size: 4
#   Early stop: patience=10 | checkpoint by Val F1/AUC
#   Params    : 4,607,359
#   Trainable : 599,811  (backbone frozen)
# ------------------------------------------------------------

# %%
print("TRAINING STARTED")
for epoch in range(EPOCHS):

    # Progressive unfreezing improves accuracy while reducing early overfitting.
    if epoch == 8:
        print("\nEpoch 8: Unfreezing last EfficientNet blocks...")
        for block in model.video_backbone[-2:]:
            for param in block.parameters():
                param.requires_grad = True
        print(f"  Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

    if epoch == 16:
        print("\nEpoch 16: Unfreezing more EfficientNet blocks with low LR...")
        for block in model.video_backbone[-4:]:
            for param in block.parameters():
                param.requires_grad = True
        print(f"  Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

    model.train()
    total_train_loss, train_preds_all, train_labels_all = 0.0, [], []

    for video, audio, labels_batch in tqdm(train_loader,
                                           desc=f"Epoch {epoch+1}/{EPOCHS} [TRAIN]"):
        video, audio = video.to(DEVICE), audio.to(DEVICE)
        labels_batch = labels_batch.float().unsqueeze(1).to(DEVICE)
        labels_smooth = labels_batch * (1 - LABEL_SMOOTH) + LABEL_SMOOTH / 2

        optimizer.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(enabled=(USE_AMP and DEVICE.type == "cuda")):
            logits = model(video, audio)
            loss   = criterion(logits, labels_smooth)

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        scaler.step(optimizer)
        scaler.update()

        total_train_loss += loss.item()
        train_preds_all.extend((torch.sigmoid(logits.detach()) > 0.5).long().cpu().numpy().flatten())
        train_labels_all.extend(labels_batch.long().cpu().numpy().flatten())

    avg_train_loss = total_train_loss / len(train_loader)
    train_acc      = accuracy_score(train_labels_all, train_preds_all)

    model.eval()
    total_val_loss, val_preds_all, val_probs_all, val_labels_all = 0.0, [], [], []

    with torch.no_grad():
        for video, audio, labels_batch in tqdm(val_loader,
                                               desc=f"Epoch {epoch+1}/{EPOCHS} [VAL]"):
            video, audio = video.to(DEVICE), audio.to(DEVICE)
            labels_batch = labels_batch.float().unsqueeze(1).to(DEVICE)
            with torch.cuda.amp.autocast(enabled=(USE_AMP and DEVICE.type == "cuda")):
                logits = model(video, audio)
                loss   = criterion(logits, labels_batch)
            total_val_loss += loss.item()
            probs = torch.sigmoid(logits)
            val_probs_all.extend(probs.cpu().numpy().flatten())
            val_preds_all.extend((probs > 0.5).long().cpu().numpy().flatten())
            val_labels_all.extend(labels_batch.long().cpu().numpy().flatten())

    avg_val_loss = total_val_loss / len(val_loader)
    val_acc      = accuracy_score(val_labels_all, val_preds_all)
    val_f1       = f1_score(val_labels_all, val_preds_all, zero_division=0)
    val_auc      = roc_auc_score(val_labels_all, val_probs_all) if len(np.unique(val_labels_all)) == 2 else 0.0
    current_lr   = optimizer.param_groups[1]["lr"]

    print(f"\nEpoch {epoch+1}/{EPOCHS} | "
          f"Train: {avg_train_loss:.4f} ({train_acc*100:.1f}%) | "
          f"Val: {avg_val_loss:.4f} ({val_acc*100:.1f}%) | "
          f"F1: {val_f1:.4f} | AUC: {val_auc:.4f} | "
          f"LR: {current_lr:.2e}")

    scheduler.step(avg_val_loss)

    is_better = (val_f1 > best_val_f1) or (val_f1 == best_val_f1 and val_auc > best_val_auc)
    if is_better:
        best_val_loss = avg_val_loss
        best_val_f1   = val_f1
        best_val_auc  = val_auc
        es_counter    = 0
        torch.save(model.state_dict(), f"/kaggle/working/best_model_{RESULT_TAG}.pth")
        print(f"  Saved best model -> /kaggle/working/best_model_{RESULT_TAG}.pth")
        print(f"  Best so far: F1={best_val_f1:.4f}, AUC={best_val_auc:.4f}")
    else:
        es_counter += 1
        print(f"  No F1/AUC improvement ({es_counter}/{ES_PATIENCE})")

    if es_counter >= ES_PATIENCE:
        print(f"\nEarly stopping triggered at epoch {epoch+1}.")
        break

print("\nTRAINING COMPLETE")
# Out:
# TRAINING STARTED
# Epoch 1/35 [TRAIN]: 100%|██████████| 240/240 [02:32<00:00,  1.58it/s]
# Epoch 1/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 1/35 | Train: 0.4946 (81.7%) | Val: 0.2974 (89.6%) | F1: 0.8858 | AUC: 0.9751 | LR: 2.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.8858, AUC=0.9751
# Epoch 2/35 [TRAIN]: 100%|██████████| 240/240 [02:30<00:00,  1.60it/s]
# Epoch 2/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.82it/s]
# Epoch 2/35 | Train: 0.4013 (87.7%) | Val: 0.1688 (95.0%) | F1: 0.9483 | AUC: 0.9779 | LR: 2.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9483, AUC=0.9779
# Epoch 3/35 [TRAIN]: 100%|██████████| 240/240 [02:23<00:00,  1.67it/s]
# Epoch 3/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 3/35 | Train: 0.3646 (89.5%) | Val: 0.1723 (95.4%) | F1: 0.9524 | AUC: 0.9797 | LR: 2.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9524, AUC=0.9797
# Epoch 4/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 4/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 4/35 | Train: 0.3906 (87.4%) | Val: 0.2819 (90.0%) | F1: 0.8899 | AUC: 0.9715 | LR: 2.00e-04
#   No F1/AUC improvement (1/10)
# Epoch 5/35 [TRAIN]: 100%|██████████| 240/240 [02:22<00:00,  1.68it/s]
# Epoch 5/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.80it/s]
# Epoch 5/35 | Train: 0.3551 (89.4%) | Val: 0.2013 (95.4%) | F1: 0.9524 | AUC: 0.9743 | LR: 2.00e-04
#   No F1/AUC improvement (2/10)
# Epoch 6/35 [TRAIN]: 100%|██████████| 240/240 [02:27<00:00,  1.63it/s]
# Epoch 6/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.82it/s]
# Epoch 6/35 | Train: 0.3347 (89.7%) | Val: 0.1951 (93.3%) | F1: 0.9298 | AUC: 0.9757 | LR: 2.00e-04
#   No F1/AUC improvement (3/10)
# Epoch 7/35 [TRAIN]: 100%|██████████| 240/240 [02:24<00:00,  1.66it/s]
# Epoch 7/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 7/35 | Train: 0.3394 (90.3%) | Val: 0.1650 (94.6%) | F1: 0.9432 | AUC: 0.9807 | LR: 1.00e-04
#   No F1/AUC improvement (4/10)
# Epoch 8/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 8/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 8/35 | Train: 0.3326 (90.1%) | Val: 0.2077 (93.3%) | F1: 0.9286 | AUC: 0.9788 | LR: 1.00e-04
#   No F1/AUC improvement (5/10)
#
# Epoch 8: Unfreezing last EfficientNet blocks...
#   Trainable params: 1,729,203
# Epoch 9/35 [TRAIN]: 100%|██████████| 240/240 [02:33<00:00,  1.57it/s]
# Epoch 9/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 9/35 | Train: 0.3243 (90.2%) | Val: 0.2167 (92.9%) | F1: 0.9238 | AUC: 0.9844 | LR: 1.00e-04
#   No F1/AUC improvement (6/10)
# Epoch 10/35 [TRAIN]: 100%|██████████| 240/240 [02:28<00:00,  1.62it/s]
# Epoch 10/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 10/35 | Train: 0.3020 (91.2%) | Val: 0.2051 (93.8%) | F1: 0.9333 | AUC: 0.9838 | LR: 1.00e-04
#   No F1/AUC improvement (7/10)
# Epoch 11/35 [TRAIN]: 100%|██████████| 240/240 [02:27<00:00,  1.62it/s]
# Epoch 11/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 11/35 | Train: 0.3157 (90.3%) | Val: 0.1572 (95.4%) | F1: 0.9528 | AUC: 0.9815 | LR: 1.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9528, AUC=0.9815
# Epoch 12/35 [TRAIN]: 100%|██████████| 240/240 [02:21<00:00,  1.69it/s]
# Epoch 12/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 12/35 | Train: 0.3296 (89.8%) | Val: 0.1692 (95.4%) | F1: 0.9524 | AUC: 0.9835 | LR: 1.00e-04
#   No F1/AUC improvement (1/10)
# Epoch 13/35 [TRAIN]: 100%|██████████| 240/240 [02:37<00:00,  1.52it/s]
# Epoch 13/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 13/35 | Train: 0.3300 (89.9%) | Val: 0.1556 (95.4%) | F1: 0.9528 | AUC: 0.9784 | LR: 1.00e-04
#   No F1/AUC improvement (2/10)
# Epoch 14/35 [TRAIN]: 100%|██████████| 240/240 [02:21<00:00,  1.70it/s]
# Epoch 14/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 14/35 | Train: 0.2962 (92.1%) | Val: 0.1451 (96.2%) | F1: 0.9610 | AUC: 0.9892 | LR: 1.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9610, AUC=0.9892
# Epoch 15/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 15/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 15/35 | Train: 0.2756 (92.9%) | Val: 0.1465 (95.8%) | F1: 0.9569 | AUC: 0.9884 | LR: 1.00e-04
#   No F1/AUC improvement (1/10)
# Epoch 16/35 [TRAIN]: 100%|██████████| 240/240 [02:27<00:00,  1.63it/s]
# Epoch 16/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.84it/s]
# Epoch 16/35 | Train: 0.2863 (92.3%) | Val: 0.1614 (93.3%) | F1: 0.9292 | AUC: 0.9890 | LR: 1.00e-04
#   No F1/AUC improvement (2/10)
#
# Epoch 16: Unfreezing more EfficientNet blocks with low LR...
#   Trainable params: 4,298,699
# Epoch 17/35 [TRAIN]: 100%|██████████| 240/240 [02:46<00:00,  1.44it/s]
# Epoch 17/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 17/35 | Train: 0.2919 (91.4%) | Val: 0.1323 (96.7%) | F1: 0.9655 | AUC: 0.9893 | LR: 1.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9655, AUC=0.9893
# Epoch 18/35 [TRAIN]: 100%|██████████| 240/240 [02:28<00:00,  1.61it/s]
# Epoch 18/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 18/35 | Train: 0.2551 (93.2%) | Val: 0.1811 (94.6%) | F1: 0.9427 | AUC: 0.9903 | LR: 1.00e-04
#   No F1/AUC improvement (1/10)
# Epoch 19/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 19/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.78it/s]
# Epoch 19/35 | Train: 0.3096 (90.4%) | Val: 0.1902 (94.2%) | F1: 0.9381 | AUC: 0.9891 | LR: 1.00e-04
#   No F1/AUC improvement (2/10)
# Epoch 20/35 [TRAIN]: 100%|██████████| 240/240 [02:27<00:00,  1.62it/s]
# Epoch 20/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 20/35 | Train: 0.2898 (91.8%) | Val: 0.1676 (95.4%) | F1: 0.9520 | AUC: 0.9853 | LR: 1.00e-04
#   No F1/AUC improvement (3/10)
# Epoch 21/35 [TRAIN]: 100%|██████████| 240/240 [02:28<00:00,  1.62it/s]
# Epoch 21/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 21/35 | Train: 0.2880 (92.0%) | Val: 0.1314 (96.7%) | F1: 0.9655 | AUC: 0.9882 | LR: 1.00e-04
#   No F1/AUC improvement (4/10)
# Epoch 22/35 [TRAIN]: 100%|██████████| 240/240 [02:30<00:00,  1.60it/s]
# Epoch 22/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.78it/s]
# Epoch 22/35 | Train: 0.2873 (91.5%) | Val: 0.1344 (96.7%) | F1: 0.9655 | AUC: 0.9853 | LR: 1.00e-04
#   No F1/AUC improvement (5/10)
# Epoch 23/35 [TRAIN]: 100%|██████████| 240/240 [02:23<00:00,  1.67it/s]
# Epoch 23/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.80it/s]
# Epoch 23/35 | Train: 0.2488 (93.0%) | Val: 0.1441 (96.2%) | F1: 0.9614 | AUC: 0.9802 | LR: 1.00e-04
#   No F1/AUC improvement (6/10)
# Epoch 24/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 24/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 24/35 | Train: 0.2776 (91.0%) | Val: 0.1353 (96.7%) | F1: 0.9655 | AUC: 0.9861 | LR: 1.00e-04
#   No F1/AUC improvement (7/10)
# Epoch 25/35 [TRAIN]: 100%|██████████| 240/240 [02:37<00:00,  1.52it/s]
# Epoch 25/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.78it/s]
# Epoch 25/35 | Train: 0.2528 (93.1%) | Val: 0.1415 (96.7%) | F1: 0.9658 | AUC: 0.9845 | LR: 1.00e-04
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9658, AUC=0.9845
# Epoch 26/35 [TRAIN]: 100%|██████████| 240/240 [02:27<00:00,  1.63it/s]
# Epoch 26/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.83it/s]
# Epoch 26/35 | Train: 0.2496 (93.2%) | Val: 0.1571 (94.6%) | F1: 0.9456 | AUC: 0.9853 | LR: 5.00e-05
#   No F1/AUC improvement (1/10)
# Epoch 27/35 [TRAIN]: 100%|██████████| 240/240 [02:29<00:00,  1.60it/s]
# Epoch 27/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 27/35 | Train: 0.2359 (93.2%) | Val: 0.1380 (96.7%) | F1: 0.9658 | AUC: 0.9872 | LR: 5.00e-05
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9658, AUC=0.9872
# Epoch 28/35 [TRAIN]: 100%|██████████| 240/240 [02:22<00:00,  1.69it/s]
# Epoch 28/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.85it/s]
# Epoch 28/35 | Train: 0.2000 (96.2%) | Val: 0.1388 (96.2%) | F1: 0.9614 | AUC: 0.9866 | LR: 5.00e-05
#   No F1/AUC improvement (1/10)
# Epoch 29/35 [TRAIN]: 100%|██████████| 240/240 [02:31<00:00,  1.58it/s]
# Epoch 29/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 29/35 | Train: 0.2374 (93.2%) | Val: 0.1502 (95.0%) | F1: 0.9478 | AUC: 0.9893 | LR: 5.00e-05
#   No F1/AUC improvement (2/10)
# Epoch 30/35 [TRAIN]: 100%|██████████| 240/240 [02:24<00:00,  1.67it/s]
# Epoch 30/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.81it/s]
# Epoch 30/35 | Train: 0.2504 (92.5%) | Val: 0.1365 (95.8%) | F1: 0.9569 | AUC: 0.9908 | LR: 2.50e-05
#   No F1/AUC improvement (3/10)
# Epoch 31/35 [TRAIN]: 100%|██████████| 240/240 [02:25<00:00,  1.65it/s]
# Epoch 31/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.84it/s]
# Epoch 31/35 | Train: 0.2363 (93.6%) | Val: 0.1379 (96.2%) | F1: 0.9614 | AUC: 0.9909 | LR: 2.50e-05
#   No F1/AUC improvement (4/10)
# Epoch 32/35 [TRAIN]: 100%|██████████| 240/240 [02:36<00:00,  1.53it/s]
# Epoch 32/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.80it/s]
# Epoch 32/35 | Train: 0.2447 (93.0%) | Val: 0.1324 (95.8%) | F1: 0.9576 | AUC: 0.9859 | LR: 2.50e-05
#   No F1/AUC improvement (5/10)
# Epoch 33/35 [TRAIN]: 100%|██████████| 240/240 [02:19<00:00,  1.72it/s]
# Epoch 33/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.80it/s]
# Epoch 33/35 | Train: 0.2318 (94.0%) | Val: 0.1468 (95.4%) | F1: 0.9520 | AUC: 0.9921 | LR: 2.50e-05
#   No F1/AUC improvement (6/10)
# Epoch 34/35 [TRAIN]: 100%|██████████| 240/240 [02:26<00:00,  1.63it/s]
# Epoch 34/35 [VAL]: 100%|██████████| 60/60 [00:32<00:00,  1.82it/s]
# Epoch 34/35 | Train: 0.2118 (94.8%) | Val: 0.1313 (96.7%) | F1: 0.9658 | AUC: 0.9881 | LR: 1.25e-05
#   Saved best model -> /kaggle/working/best_model_efficientnet_tsmote_balancing.pth
#   Best so far: F1=0.9658, AUC=0.9881
# Epoch 35/35 [TRAIN]: 100%|██████████| 240/240 [02:26<00:00,  1.63it/s]
# Epoch 35/35 [VAL]: 100%|██████████| 60/60 [00:33<00:00,  1.79it/s]
# Epoch 35/35 | Train: 0.2354 (93.3%) | Val: 0.1323 (96.2%) | F1: 0.9617 | AUC: 0.9880 | LR: 1.25e-05
#   No F1/AUC improvement (1/10)
#
# TRAINING COMPLETE

# %%
model.load_state_dict(torch.load(f"/kaggle/working/best_model_{RESULT_TAG}.pth", map_location=DEVICE))
model.eval()
all_probs, all_labels_eval = [], []

with torch.no_grad():
    for video, audio, labels in val_loader:
        video, audio = video.to(DEVICE), audio.to(DEVICE)
        with torch.cuda.amp.autocast(enabled=(USE_AMP and DEVICE.type == "cuda")):
            logits = model(video, audio)
        all_probs.extend(torch.sigmoid(logits).cpu().numpy().flatten())
        all_labels_eval.extend(labels.numpy().flatten())

all_probs       = np.array(all_probs)
all_labels_eval = np.array(all_labels_eval)

best_f1, best_thresh = 0.0, 0.5
for thresh in np.arange(0.3, 0.9, 0.01):
    preds = (all_probs > thresh).astype(int)
    f1    = f1_score(all_labels_eval, preds, zero_division=0)
    if f1 > best_f1:
        best_f1, best_thresh = f1, thresh

final_preds   = (all_probs > best_thresh).astype(int)
final_metrics = {
    "Architecture"    : "EfficientNet-B0 + GRU + Attention",
    "Balancing"       : BALANCING_NAME,
    "Train_Samples"   : len(train_paths),
    "Synthetic_Slots" : augmented_count,
    "Threshold"       : float(best_thresh),
    "Accuracy"        : accuracy_score(all_labels_eval, final_preds),
    "Precision"       : precision_score(all_labels_eval, final_preds, zero_division=0),
    "Recall"          : recall_score(all_labels_eval, final_preds, zero_division=0),
    "F1_Score"        : f1_score(all_labels_eval, final_preds, zero_division=0),
    "AUC"             : roc_auc_score(all_labels_eval, all_probs),
    "Best_Val_F1"     : best_val_f1,
    "Best_Val_AUC"    : best_val_auc
}

print(f"FINAL METRICS (threshold={best_thresh:.2f}):")
for k, v in final_metrics.items():
    if isinstance(v, (int, float, np.integer, np.floating)):
        print(f"  {k:16s}: {v:.4f}")
    else:
        print(f"  {k:16s}: {v}")

cm = confusion_matrix(all_labels_eval, final_preds)
print("\nCONFUSION MATRIX:")
print(cm)
print("\nCLASSIFICATION REPORT:")
print(classification_report(all_labels_eval, final_preds, target_names=["Real", "Fake"], zero_division=0))

metrics_path = f"/kaggle/working/metrics_{RESULT_TAG}.csv"
pd.DataFrame([final_metrics]).to_csv(metrics_path, index=False)
print(f"Saved metrics -> {metrics_path}")
# Out:
# FINAL METRICS (threshold=0.67):
#   Architecture    : EfficientNet-B0 + GRU + Attention
#   Balancing       : T-SMOTE temporal interpolation
#   Train_Samples   : 960.0000
#   Synthetic_Slots : 100.0000
#   Threshold       : 0.6700
#   Accuracy        : 0.9708
#   Precision       : 1.0000
#   Recall          : 0.9417
#   F1_Score        : 0.9700
#   AUC             : 0.9881
#   Best_Val_F1     : 0.9658
#   Best_Val_AUC    : 0.9881
#
# CONFUSION MATRIX:
# [[120   0]
#  [  7 113]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#         Real       0.94      1.00      0.97       120
#         Fake       1.00      0.94      0.97       120
#
#     accuracy                           0.97       240
#    macro avg       0.97      0.97      0.97       240
# weighted avg       0.97      0.97      0.97       240
#
# Saved metrics -> /kaggle/working/metrics_efficientnet_tsmote_balancing.csv

# %%
plt.figure(figsize=(15, 5))

plt.subplot(131)
plt.hist(all_probs[all_labels_eval == 0], alpha=0.5, label="Real", bins=20)
plt.hist(all_probs[all_labels_eval == 1], alpha=0.5, label="Fake", bins=20)
plt.axvline(best_thresh, color="red", linestyle="--", label=f"Thresh={best_thresh:.2f}")
plt.legend(); plt.title("Prediction Distribution")

plt.subplot(132)
fpr, tpr, _ = roc_curve(all_labels_eval, all_probs)
plt.plot(fpr, tpr, label=f'AUC={final_metrics["AUC"]:.3f}')
plt.plot([0, 1], [0, 1], "k--"); plt.legend(); plt.title("ROC Curve")

plt.subplot(133)
summary = (f"Arch  : EfficientNet-B0 + GRU\n"
           f"Balance: {BALANCING_NAME}\n"
           f"Val   : {VAL_SIZE} samples\n"
           f"Train : {len(train_paths)} samples\n"
           f"Synth : {augmented_count} slots\n"
           f"AUC   : {final_metrics['AUC']:.3f}\n"
           f"F1    : {final_metrics['F1_Score']:.3f}\n"
           f"Thresh: {best_thresh:.2f}")
plt.text(0.05, 0.35, summary, fontsize=11, verticalalignment="center",
         fontfamily="monospace")
plt.axis("off"); plt.title("Run Summary")

plt.tight_layout()
plt.savefig(f"/kaggle/working/results_{RESULT_TAG}.png", dpi=150)
plt.show()
print(f"\nCOMPLETE! Saved: /kaggle/working/best_model_{RESULT_TAG}.pth  |  /kaggle/working/results_{RESULT_TAG}.png")
# Out:
# COMPLETE! Saved: /kaggle/working/best_model_efficientnet_tsmote_balancing.pth  |  /kaggle/working/results_efficientnet_tsmote_balancing.png
